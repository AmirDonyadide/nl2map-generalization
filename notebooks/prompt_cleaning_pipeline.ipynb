# %%
# --- Environment & imports ---
from dotenv import load_dotenv
import os
import re
import json
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm
from langdetect import detect, DetectorFactory
from openai import OpenAI

# Load .env file (THIS is the missing step)
load_dotenv()

# Sanity check (fail fast)
assert os.getenv("OPENAI_API_KEY"), "OPENAI_API_KEY not found. Check your .env file."

# Init OpenAI client
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# Reproducibility
DetectorFactory.seed = 42
tqdm.pandas()

# Paths
DATA_DIR = Path("..") / "data" / "userstudy"
DATA_DIR
# Out:
# PosixPath('../data/userstudy')

# %%
INPUT_RAW_CSV = DATA_DIR / "UserStudy - Responses.csv"

df = pd.read_csv(INPUT_RAW_CSV)
assert "free_text" in df.columns, "CSV must contain column 'free_text'"

df["free_text"] = df["free_text"].astype(str).str.strip()
df.loc[df["free_text"].isin(["", "nan", "None"]), "free_text"] = np.nan

OUT0_CSV  = DATA_DIR / "step0_raw_cleaned.csv"
OUT0_XLSX = DATA_DIR / "step0_raw_cleaned.xlsx"

df.to_csv(OUT0_CSV, index=False)
df.to_excel(OUT0_XLSX, index=False)

print("Saved:", OUT0_CSV.name, "and", OUT0_XLSX.name)
# Out:
# Saved: step0_raw_cleaned.csv and step0_raw_cleaned.xlsx

# %%
def safe_detect_lang(text: str) -> str:
    if text is None or not isinstance(text, str):
        return "unknown"
    t = text.strip()
    if not t:
        return "unknown"
    try:
        return detect(t)
    except:
        return "unknown"


PROMPT_DETECT_SYSTEM = "You are a strict classifier for user-study responses."

PROMPT_DETECT_USER_TEMPLATE = """Decide if the text is a usable user prompt for map generalization.

Return ONLY one token:
- PROMPT
- NOT_PROMPT

Text:
{TEXT}
"""

def looks_like_prompt_llm(text: str, model="gpt-4o-mini") -> bool:
    if text is None or not isinstance(text, str) or not text.strip():
        return False
    msg = PROMPT_DETECT_USER_TEMPLATE.format(TEXT=text.strip())
    r = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role":"system", "content": PROMPT_DETECT_SYSTEM},
            {"role":"user", "content": msg},
        ],
    )
    return r.choices[0].message.content.strip() == "PROMPT"

# %%
IN1_XLSX = DATA_DIR / "step0_raw_cleaned.xlsx"
df = pd.read_excel(IN1_XLSX)

assert "free_text" in df.columns

df["step1_is_prompt"] = df["free_text"].progress_apply(looks_like_prompt_llm)
df["step1_text"] = df["free_text"].where(df["step1_is_prompt"], np.nan)

# audit drop reason
df["drop_reason"] = np.nan
df.loc[df["free_text"].isna(), "drop_reason"] = "empty_free_text"
df.loc[df["free_text"].notna() & (~df["step1_is_prompt"]), "drop_reason"] = "not_prompt_like"

OUT1_CSV  = DATA_DIR / "step1_prompt_detected.csv"
OUT1_XLSX = DATA_DIR / "step1_prompt_detected.xlsx"
df.to_csv(OUT1_CSV, index=False)
df.to_excel(OUT1_XLSX, index=False)

print("Saved:", OUT1_CSV.name, "and", OUT1_XLSX.name)
# Out:
# 100%|██████████| 786/786 [07:45<00:00,  1.69it/s]
# Saved: step1_prompt_detected.csv and step1_prompt_detected.xlsx
# /var/folders/6r/lw1cp6x117zfdkxgl862fymc0000gn/T/ipykernel_99220/561570398.py:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'empty_free_text' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["free_text"].isna(), "drop_reason"] = "empty_free_text"

# %%
TRANSLATE_SYSTEM = "You translate text to English with high fidelity."

TRANSLATE_USER_TEMPLATE = """Translate the following text into English.

Rules:
- Preserve meaning and tone.
- Keep it as a prompt/command.
- Do NOT add new information.
- Output a single line only.

Text:
{TEXT}
"""

def translate_to_english(text: str, model="gpt-4o-mini") -> str:
    if text is None or not isinstance(text, str) or not text.strip():
        return np.nan
    msg = TRANSLATE_USER_TEMPLATE.format(TEXT=text.strip())
    r = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role":"system", "content": TRANSLATE_SYSTEM},
            {"role":"user", "content": msg},
        ],
    )
    return r.choices[0].message.content.strip()


IN2_XLSX = DATA_DIR / "step1_prompt_detected.xlsx"
df = pd.read_excel(IN2_XLSX)

df["step1_lang"] = df["step1_text"].apply(lambda x: safe_detect_lang(x) if isinstance(x, str) else "unknown")

need_translate = df["step1_is_prompt"] & (df["step1_lang"] != "en") & df["step1_text"].notna()

df["step2_text"] = np.nan
df.loc[df["step1_is_prompt"] & (df["step1_lang"] == "en"), "step2_text"] = df.loc[
    df["step1_is_prompt"] & (df["step1_lang"] == "en"),
    "step1_text"
]

df.loc[need_translate, "step2_text"] = df.loc[need_translate, "step1_text"].progress_apply(translate_to_english)

OUT2_CSV  = DATA_DIR / "step2_translated.csv"
OUT2_XLSX = DATA_DIR / "step2_translated.xlsx"
df.to_csv(OUT2_CSV, index=False)
df.to_excel(OUT2_XLSX, index=False)

print("Saved:", OUT2_CSV.name, "and", OUT2_XLSX.name)
# Out:
# /var/folders/6r/lw1cp6x117zfdkxgl862fymc0000gn/T/ipykernel_99220/4112793507.py:38: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['I want to use the map on the right side because some unnecessary details have been removed.'
#  'I want to use the map on the right side because the buildings under 100 square feet have been removed.'
#  'I want to use the map on the right side because unnecessary details have been removed.'
#  'I want to use the map on the left side because on the right side, the buildings are not properly separated.'
#  'I want to use the map on the right because buildings under 100 square meters have been removed.'
#  'merge neighbouring building polygons by removing small gaps between them'
#  'remove small buildings, simplify the building outlines, and reduce detail by eliminating minor shapes.'
#  'remove very small buildings, simplify building outlines, and make remaining shapes more rectangular and uniform.'
#  'slightly enlarge and regularize building shapes while removing very small fragments.'
#  'remove very small buildings and slightly simplify irregular building outlines.'
#  'remove the smallest buildings and slightly straighten or simplify building outlines.'
#  'remove the smallest building fragments and slightly regularize the larger building shapes.'
#  'remove tiny building fragments and simplify the outlines of irregular buildings.'
#  'remove tiny building fragments and slightly simplify the shapes of the remaining buildings.'
#  'I want to use the map on the right because buildings under 100 square meters have been removed.'
#  'remove very small building fragments and smooth or regularize the shapes of the remaining buildings.'
#  'I want to use the map on the right because buildings under 100 square meters have been removed.'
#  'remove tiny buildings and simplify irregular building footprints into smoother, more unified shapes.'
#  'remove many small buildings, enlarge and simplify the remaining ones, and reduce dense clusters into fewer, clearer shapes'
#  'remove very small buildings and simplify the outlines of the remaining ones.'
#  'remove many very small buildings and slightly smooth or regularize the outlines of the remaining ones'
#  'remove most of the smaller and closely spaced buildings, keeping only larger, more isolated ones with slightly simplified shapes'
#  'remove the smallest buildings and slightly simplify the shapes of the remaining ones.'
#  'remove very small buildings and simplify the shapes of the remaining ones into cleaner, less detailed polygons'
#  'remove the smallest buildings and simplify dense building clusters into fewer, clearer shapes'
#  'remove many small buildings, reduce dense clusters, and simplify remaining building shapes into clearer polygons'
#  'remove very small buildings and slightly straighten or simplify the outlines of the remaining ones'
#  'remove very small buildings and simplify the remaining building shapes into cleaner, more regular polygons'
#  'remove very small buildings and simplify the outlines of larger buildings into clearer, more uniform polygons'
#  'remove very small buildings and simplify the outlines of the remaining buildings into smoother polygons.'
#  'merge nearby buildings, remove very small buildings, and simplify the shapes'
#  'removing the parcels which their areas is smaller than a certain amount'
#  'remove small details and make building shapes more uniform”'
#  'Apply minimal outline smoothing with very slight shape adjustments'
#  'simplifying the outlines (removing the extra parts attached to parcels)'
#  'keeping the outlines a straight line (removing extra parts outside each outline)'
#  'Remove  small buildings, simplify building shapes, and smooth the outlines'
#  'Remove small buildings and simplify the building shapes'
#  'omitting parcels smaller than a certain amount'
#  'smoothing out the outlines for example on the two top parcels at 400 meters'
#  'Rotate and regularize building shapes, smooth the corners, and lightly simplify the outlines'
#  'Remove most small buildings and retain only the larger ones'
#  'Remove most small buildings and retain only the larger ones'
#  'Merge nearby buildings into larger blocks and simplify the resulting shapes'
#  'Remove a few small buildings'
#  'deleting parcels smaller than their neighbors'
#  'Merge very close buildings into larger unified blocks'
#  'deleting extra parts of parcels with more than 4 sides'
#  'Remove most small buildings, merge nearby ones, and simplify the building shapes'
#  'smoothing out the outlines' 'merge buildings nearby ones'
#  'Slightly adjust building shapes and smooth the outlines with minimal changes'
#  'Apply very slight outline smoothing and minor angle adjustments'
#  'Remove small buildings and simplify the shapes of the remaining ones'
#  'delete parcels which are so close to each other and delete the smaller one'
#  'Merge nearby buildings and unify fragmented blocks'
#  'move the two parcels on the right on 100 meters further away from each other'
#  'Remove some building clusters and soften the shapes of others'
#  'fill the edges between two parcels which their gap is a very thin line'
#  'Remove very small buildings' 'Remove very small buildings'
#  'Remove some building clusters and soften the shapes of others'
#  'place the small parcels between two big parcels in the middle of them and keep just one of them'
#  'attach the parcels with very small distance between them together'
#  'make very close parcels unified'
#  'make very close parcels unified so they shape a form together'
#  'blur the parcels (no change)' 'filter parcels with a tereshold on area'
#  'union the parcels and then MBR'
#  'remove blocks having more than 3 cells in which each cell is 5 meters'
#  'convert blocks having cells into one single cell'
#  'Combine the neighbors being in range of these coordinates (250,200) and (350, 250)'
#  'remove the cells equal to or smaller than 5 sqm'
#  'separate cells being on top of each other by putting them next to each other'
#  'remove the cells that have the smallest among the neighbors, keeping only the greatest one'
#  'convert the rectangular cells that have a rectangular extension into a trapezoid'
#  'convert the zigzag corners of neighbors into a trapezoid'
#  'convert the cells having rectangular extension into a trapezoid'
#  'make the neighbor one single cell'
#  'turn the cells having rectangular parts into a trapezoid'
#  'make the cells which have rectangular extension into a trapezoid'
#  'make the sides that are like "L" a single straight line'
#  'remove the cells smaller than 10sqm' 'combine all the nieghbors'
#  'combine all the neighbors'
#  'remove the blocks having cells smaller than 10m'
#  'Distance the cells by 5m between these coordinates (100, 0-100) and (200,0-100)'
#  'remove the cells having a size smaller than 5 sqm area'
#  'combine neighbour buildings together'
#  'remove buildings smaller than 100 sqaured meters'
#  'remove some small buildings' 'combine neighbour buildings together'
#  'merge neighbour buildings together'
#  'combine neighbour buildings and remove the smalls'
#  'Merge the blocks that are adjacent to each other.'
#  'make convex hall of buildings' 'combine neighbour buildings together'
#  'make convex hall of buildings'
#  'Remove the parts that extend beyond the block boundaries, and refine the block shapes.'
#  'remove the middle buildings'
#  'remove buildings smaller than 100 squared meter'
#  'Remove the blocks that are smaller than a threshold.'
#  'combine neighbour buildings together' 'make convex hall of buildings'
#  'remove buildings smaller than 100 squared meter'
#  'Merge the blocks that are aligned in the same direction.'
#  'remove buildings smaller than 100 squared meter'
#  'remove buildings smaller than 100 squared meter'
#  'make convex hall of buildings' 'combine neighbour buildings together'
#  'refine the spaces between the blocks.' 'make convex hall of buildings'
#  'remove buildings smaller than 100 squared meter'
#  'Merge the nearby blocks and regularize their geometric shape.'
#  'Increase the spacing between the blocks that are closer than a threshold, or reduce the size of one of the blocks.'
#  'Remove consecutive blocks that are similar to each other.'
#  'Remove the blocks that are smaller than a threshold and located between other blocks.'
#  'Merge small blocks with their nearest block.'
#  'Merge the blocks that are closer than a threshold.'
#  'Give geometric shapes to the blocks.'
#  'Remove the blocks that are smaller than a threshold and located between other blocks.'
#  'refine the shape of blocks.' 'Fill the gaps between the blocks.'
#  'Remove the blocks that are smaller than a threshold.'
#  'Increase the spacing between the blocks that are closer than a threshold.'
#  'Merge the blocks that are closer than a threshold and refine the shape of blocks.'
#  'Remove the blocks that are smaller than a threshold.'
#  'Merge nearby blocks, fill the gaps between them, and refine their shapes.'
#  'Remove the blocks that are smaller than a threshold'
#  'Refine the shape and boundaries of the blocks.'
#  'Refine the shape and boundaries of blocks.'
#  'Refine the shape of blocks.'
#  'connect peaces together with distance less than X.'
#  'remove overhangs (protrusions) with size less than Y'
#  'if the distance between two pieces is more than Z, make that distance Z+delta'
#  'Simplify the parcels by deleting their vertices that are closer than 0.2 m to each other'
#  'remove all the parcels smaller than 10 sqm'
#  'merge the aprcels if the minimum distance between their vertices is less than 1m'
#  'delete the parcels smaller than 5 sqm'
#  'union the parcels with the nearest parcel in a 10m radius, repeat the process until there is no single parcel in the 10m radius'
#  'remove pieces in quadrilateral shape and area less than A'
#  'remove pieces with area less than a threshold'
#  'merge neighboring pieces together, neighboring is defined by distance less than M between two pieces'
#  'remove pieces with area less than a threshold'
#  'make a space of 3 sqm between the parcels which are closer than 1m ro each other'
#  'remove pieces with area less than a threshold'
#  'Simplify the polygons with the Douglas-Peucker algorithm with the epsilon=3'
#  'remove pieces with area less than a threshold'
#  'Make a space of 5sqm between the polygons in the coordinates of (180, 88)'
#  'Convert to regular geometric shapes or a combination of regular geometric shapes'
#  'merge the neighboring pieces'
#  'Simplify the polygons by deleting vertices that are very close'
#  'connect the neighboring pieces by filling the gaps between them'
#  'remove parcels with area less than X'
#  'separate the polygons that have overlap with each other'
#  'Convert each piece to a regular geometric shape or a combination of regular geometric shapes'
#  'Convert to regular geometric shapes' 'separate the overlapped polygones'
#  'remove all the parcels smaller than 5 sqm'
#  'Delete all the parcels smaller than 3 sqm'
#  'simplify the polygons with the Douglas-Peucker algorithm with epsilon=5m'
#  'make a space of 3sqm between the polygons that are closer than 1m to each other'
#  'Simplify the map by deleting the objects smaller than 2sqm and merging the polygons closer than 0.5m to each other'
#  'union a polygon to the closest polygons if it is smaller than 3sqm'
#  'simplify polygons with Douglas-Peucker algorithm with epsilon=3m'
#  'Delete the polygons smaller than 5sqm'
#  'union the polygons that closer than 0.5m to each other'
#  'union the polygons that are closer than 1m to each other'
#  'Reduce the number of vertices in each polygon to less than or equal to 4 if it has more. remove the vertices between the smallestedges'
#  'union the parcels that are closer than 0.2m to each other'
#  'Combine the nearby buildings into one.'
#  'Separate the attached buildings'
#  'Combine the nearby buildings that are of the same size.'
#  'Remove the very small buildings'
#  'Convert the buildings into four-sided shapes'
#  'Increase the distance between the buildings at coordinates (400, 200)'
#  'Convert the buildings into quadrilaterals and remove the extra parts'
#  'Increase the spacing between the buildings'
#  'Remove the very small buildings'
#  'Convert the buildings into quadrilaterals'
#  'Delete some of the buildings'
#  'Convert the polygonal buildings into quadrilaterals'
#  'Combine the nearby buildings into one' 'Combine the nearby buildings'
#  'Remove a series of small buildings' 'Remove the small buildings'
#  'Vanish the small buildings'
#  'Increase the distance between the small buildings'
#  'Merge the nearby, similar buildings into one'
#  'Delete the very small buildings that are near each other.'
#  'Move the small buildings a little'
#  'Combine the nearby buildings into one'
#  'Make the multi-sided buildings four-cornered'
#  'remove the smaller structures'
#  'between three adjacent structure remove the smallest'
#  'reduce the level of detail'
#  'reduce the level of detail in each bulding and shape it like simple polygon'
#  'connect the nearby vertices'
#  'keep major building structures and their overall layout'
#  'connect the nearby vertices' 'split small structures into simple shapes'
#  'mutate  small shapes randomly' 'simplify  non simple polygon shapes'
#  'split  adjacent larger buildings into simpler shapes'
#  'remove  the smaller structures'
#  'merge adjacent larger buildings into simpler shapes'
#  'remove  the small shapes'
#  'Merge all the places together and unify them.'
#  '“Merge all the places together and unify them.”'
#  'Remove the locations with an area smaller than the threshold'
#  'Keep the locations that have an event.'
#  'Merge the locations and remove those with small areas'
#  'Remove the illegal houses.' 'Remove the illegal houses.'
#  'Merge the locations and remove the small ones' 'remove the small ones'
#  'Merge the locations and remove the small ones'
#  'Merge the locations and remove the small ones'
#  'Remove the unsafe houses' 'Remove the unsafe houses'
#  'Eliminate the old buildings' 'Eliminate the old buildings'
#  'Eliminate the old buildings'
#  'Remove the old houses and merge the ones that are very close to each other'
#  'Remove the old houses and merge the ones that are very close to each other'
#  'Remove the old buildings, merge those located very close to each other, and eliminate the small ones'
#  'Remove the houses in the bottom-left block' 'Remove the unsafe houses'
#  'Remove the unsafe houses' 'Remove the unsafe houses'
#  'decrease the distance between structures'
#  'Simplify the building outlines'
#  'Simplify the building outlines by merging like closing operation'
#  'reduce number of structures to half by merging adjacent blocks'
#  'remove the structures that are below the mean size of polygons'
#  'move  small polygons close toghether'
#  'make all the polygons to under 7 vertices by merging them'
#  'merge close polygons and make it united polygone'
#  'delet the small polygons in (x=0,200) and(y=100,200)'
#  'remove all the minor surrounding clutter near all the buildings, those that disrupt the overall shape and visual order. try to make them look more structed. focus more on the buildings on 400 m'
#  'merge the buildings and remove the minor distances for the buildings located 100 and 300 m away in the map'
#  'remove well-structed square buildings located 100 meters away in the map and remove curve-structed buildings'
#  'remove all the minor buildings and the greatest ones'
#  'merge all the buildings and remove all the minor distances between buildings'
#  'remove the smallest buildings in comparison with others'
#  'move the rectangular located on the 200*80 meters away in the map further'
#  'merge the building with the minimum distance except the one located 250m*200 in the map'
#  'merge all the buildings located near each other'
#  'remove unnecessary corners and change the trinangle-shaped building into trapezoid'
#  'remove unnecessary corners of the building located 400*400 m in the map'
#  'remove the minor distances and merge the buildings that are the closest to each other'
#  'remove the building located 100*100 away in the map as well as the small-area buildings and irreagular-shaped ones'
#  "remove the most small-shaped areas and merge the the ones with the minimum distances, delete the ones that can't be merged"
#  'move the two-rectangular-shaped building further to the right side of the map, make the the distances further between the buildings located 120*400 m away  in the map'
#  'focus on the 50*400 m part of the map and move the buildings further apart'
#  'remove the unnecessary corners and make the corners look more organized'
#  'merge the building with minor distances'
#  'remove the triangle-shaped building between rectangular-shaped building located 350*250 m away in the map'
#  'shape the rectangular corners into sharp triangular corners'
#  'remove the unnecessary corners and make them into triangular corners'
#  'make a major spacing between the buildings with minor distances'
#  'remove all the small-area buildings in comparison with others'
#  'Simplify building footprints by smoothing edges, removing small irregularities, and slightly adjusting positions without removing or merging buildings.'
#  'keep the overall structure, just generalize and regularize building shapes, make the small irregularities small.'
#  "try to simplify outlines, regularize building footprints by straightening edges, also remove small geometric noise, and adjust a few shapes to be more consistent. Don't change the overall layout."
#  'Simplify and regularize all building footprints by smoothing edges and cleaning small geometric noise. Apply minimal positional adjustment, but preserve every building and the overall layout.'
#  "Simplify building footprints by smoothing edges, removing small geometric noise, and lightly regularizing shapes. Don't change the overall layout"
#  "Simplify and regularize all building footprints by smoothing edges and removing small geometric noise. Don't change the overall layout"
#  'Simplify and regularize building footprints by smoothing edges and removing small geometric noise, do not change the overall look'
#  'Simplify and regularize building footprints by smoothing edges and removing small geometric noise while  keeping the same spatial layout.'
#  'keep the same overall arrangement, simplify and regularize the building footprints by smoothing edges and removing small distortions'
#  'Simplify and regularize building footprints by smoothing edges and removing small distortions, try to keep all buildings and maintain the same overall layout.'
#  'Simplify and regularize building footprints by smoothing edges and remove small distortions while  keeping the same overall layout.'
#  'Simplify and regularize all building footprints by smoothing edges and removing small distortions, maintain the same spatial structure.'
#  'Simplify and regularize building footprints by smoothing edges and cleaning small distortions, while keeping all buildings and maintaining the same overall arrangement.'
#  'Simplify and regularize building shapes by smoothing edges and removing small distortions while preserving all buildings and keeping the same layout.'
#  'Simplify and regularize building footprints by smoothing edges and removing small distortions, while preserving all buildings and keeping the same overall layout.'
#  'Simplify and regularize building footprints by smoothing edges and removing small distortions.'
#  'Simplify and regularize building footprints by smoothing edges and removing minor distortions.\nkeep the overall layout'
#  'Simplify and regularize building footprints by smoothing edges and removing small distortions. keep the same spatial layout.'
#  'Simplify and regularize building footprints by smoothing edges and removing small distortions while keeping all buildings and maintaining the same spatial layout.'
#  'Simplify and regularize building footprints by smoothing edges and eliminating small distortions, keep the same spatial arrangement.'
#  'Simplify building footprints by smoothing edges and making shapes more regular, without changing their positions, sizes, or orientations.'
#  'Keep only larger building footprints and remove small or minor structures.\n lightly smooth remaining shapes keep the overall spatial pattern.'
#  'Simplify and regularize building footprints by smoothing edges and removing tiny distortions, while keeping all buildings in the same locations and with the same general shapes'
#  'Simplify building footprints by smoothing edges and removing small shape distortions while keeping all buildings in place with their original size and orientation.'
#  'take the two irregular gray polygonal segments at the right down corner of the mao and generate a generalized, slightly stylized map-like version of it. smooth the edges slightly and make the geometry more uniform while keeping the overall silhouette recognizable.'
#  'Generalize the building in this map while preserving their approximate shapes, orientations, and spatial arrangement. Simplify each polygon.'
#  'Preserve all building positions, orientations, and overall shapes, but slightly smooth and regularize polygon edges, remove tiny irregularities.'
#  'change the number of the row of blocks which have under 10 m2 area'
#  'Generalize by simplifying block shapes, removing very small buildings, and slightly displacing overlapping features to improve readability'
#  'simplification in the corners'
#  'displacement of small blocks for make them readable'
#  'Aggregate the buildings while focusing on generating fewer buildings, bridges are allowed.'
#  'Slightly displace the buildings such that close big buildings overlap and smaller buildings get pushed apart.'
#  'Remove all smaller buildings to only keep the bigger and most important ones.'
#  'Merge connected and near building blocks to create a simpler map.'
#  'Remove small artifact buildings from the map.'
#  'Reduce the complexity of the building footprints. Sharp angles are allowed, many vertices should be removed.'
#  'Shift buildings such that neighboring buildings now overlap and bigger gaps are formed.'
#  'Move small buildings that are near a bigger building on top of the bigger building.'
#  'Remove some buildings off set the map and shift small buildings on top of their largest neighbor w.r.t. area.'
#  'Strongly simplify the buildings, I do not care about non-rectangular structures that might occur.'
#  'remove garages/carports between buildings'
#  'Merge buildings which are close to each other'
#  'dissolve the buildings into larger buildings'
#  'remove the small buildings'
#  'Merge adjacent buildings into larger polygons'
#  'merge adjacent buildings into larger buildings'
#  'Seperate the buildings if they are not adjacent'
#  'remove small buildings in the output'
#  'merge adjacent buildings into larger polygons'
#  'simplify the given buildings'
#  'displace the buildings in order to have a minimum spacing between buildings'
#  'simplify the given buildings. avoid overlaps of buildings'
#  'simplify the given buildings by removing some of the given vertices'
#  'remove adjacent groups of buildings which total area is below a given threshold'
#  'simplify the buildings sligthly. larger buildings remain unchanged'
#  'remove buildings. if two buildings are adjacent, only keep the larger one'
#  'remove small buildings, focus on sizes like garages'
#  'simplify the geometries by removing vertices'
#  'displace the buildings in order to have a similar spacing between buildings. keep garages adjacent to buildings'
#  'Simply the result slightly. keep the geometries close to the input'
#  'aggregate the buildings into larger polygons by bridging small gaps between them'
#  'displace smaller buildings to create more space inbetween'
#  'separate small adjacent buildings' 'simplify the building outlines'
#  'please aggregate small buildings' 'Move small buildings into each other'
#  'Maintain minimum distance between buildings'
#  'simplify the buildings considerably' 'simplify the building footprints'
#  'aggregate buildings into building blocks'
#  'shift some buildings randomly'
#  'only select builldings with an area larger than x squaremeters'
#  'only select building with an area larger than x square meters'
#  'only select building with an area larger than x square meters'
#  'aggregate buildings smaller than x square meters'
#  'aggregate buildings smaller than x square meters'
#  'only select building with an area larger than x square meters'
#  'simplify complex building structures' 'remove corners of the buildings'
#  'aggregate smaller buildings into larger ones'
#  'aggregate buildings into building blocks'
#  'only select buildings larger that x square meters'
#  'shift the buildings randomly'
#  'only maintain buildings larger than x square meters'
#  'separate building units from each other'
#  'Smooth and simplify the edges to make the shapes more uniform'
#  'Simplify the overall shapes and ignore the tiny edge details'
#  'Filter out the buildings smaller than 5–10 meters wide'
#  'Remove the tiny shapes with a height under 5m'
#  'Unify each shape and ignore its structural details'
#  'Smooth the edges but keep the main overall area of each shape'
#  'Emphasize the gap between adjacent shapes around  x=300m y=200'
#  'Keep the main shapes with an area not less than 100 m^2'
#  'Remove the gaps and unify the adjacent shapes'
#  'Remove the gaps and unify the adjacent shapes'
#  'Emphasize on the gap between neighbour shapes'
#  'Remove the small internal shapes in dense areas'
#  'Filter out the tiny ones with an area below about 50 m^2'
#  'Emphasize the gaps between adjacent tiny shapes in the area up to around 300 m'
#  'Smooth the edges and ignore the irregularities on their surfaces'
#  'Emphasize and expand the gaps and borders between adjacent but separate shapes'
#  'Unify the adjacent shapes but keep the neighboring ones separated'
#  'Unify the similar or identical adjacent shapes'
#  'Smooth the edges and ignore small irregularities on their overall shape'
#  'Expand the gaps between adjacent small shapes in the area with x = 100–200 and y above 300'
#  'Smooth the edges and ignore the irregularities on the surfaces'
#  'Remove the tiny in-between buildings'
#  'Remove the tiny in-between buildings'
#  'improve edges and unregular shapes'
#  'combine shapes with integrated borderline'
#  'unify the the adjacent shapes but keep the distance with neighbors'
#  'Make overlapping spaces less'
#  'Move down the object that is placed on the far right'
#  'Remove the small objects'
#  'Increase space among closely located small objects'
#  'Remove objects under a certain line'
#  'remove diverging angels and combine' 'combine shapes with a common side'
#  'combine closely located small objects'
#  'increase distance among certain objects'
#  'combine objects smaller that a certain size'
#  'remove objects smaller than a certain size'
#  'extend objects closer than a certain value and combine them'
#  'combine objects closer than a certain value'
#  'remove small objects and the objects close to them'
#  'remove objects smaller than a certain size'
#  'exclude buildings with area less than 100 square meters'
#  'exclude triangular-shaped buildings from the original one'
#  'merge the buildings when they are exactly next to each other and there is no distance between them'
#  'exclude Buildings withe area less than 100 squre meter'
#  'simplify the originial map' 'simplify the buildings in the map'
#  'merge the blocks when there is small distance between them'
#  'merge the blocks which are exactly same and next to each other'
#  'increase the distance between the smallest buildings'
#  'exclude shapes with area less than 50 square meters'
#  'merge the  smaller shape withe bigger shape which there is small distance between them'
#  'exclude shapes with area less than 10 square meters'
#  'simplify the original map'
#  'merge the similar shapes which are next to each other'
#  'exclude shapes with area less than 100 square meters'
#  'exclude shapes with area less than 100 square meters'
#  'simplify a bit the original map'
#  'Merge the buildings which are exactly aligned'
#  'Merge the aligned buildings' 'Merge the aligned buildings'
#  'Merge the aligned buildings'
#  'Simplify the edges of the buldings with too sharp corners density'
#  'Merge the building which have lower distance than … meter'
#  'Remove small buildings between 2 other buildings'
#  'Remove the small buildings between other buildings'
#  'Remove buildings smaller than specific squre meter'
#  'Remove buildings smaller than … squre meter'
#  'Remove the buildings that are too far from others'
#  'Remove buildings smaller than specific area'
#  'Remove too small buildings' 'Increase the distance between buildings'
#  'Merge the small buildings' 'Remove the small buildings'
#  'Simplify the edges of the buildings with high sharp corner density'
#  'Remove too small buildings between other buildings'
#  'Soften the corners of the buildings'
#  'Merge the buildings by expanding each builing close to the next building'
#  'Soften the edges of the buildings'
#  'Simplify the corners of the buildings'
#  'Explode the small buildings which are close to eachother'
#  'Check for gray area with a specific radius'
#  'Turn buildings with very small details into a seamless map'
#  'Change the layout of the buildings so that there are the fewest breaks in them.'
#  'Convert adjacent buildings into one building.'
#  'Expand the narrow boundaries between buildings to make their separation clear.'
#  'Remove very small buildings.'
#  'Remove buildings smaller than x Square meter.'
#  'Connect small buildings together to become a single building.'
#  'Connect small, similar buildings with narrow borders to form a single, unified building.'
#  'remove very small buildings.'
#  'Turn small buildings attached to each other into a single building.'
#  'remove very small buildings.'
#  'Turn small buildings attached to each other into a single building.'
#  'Convert curved borders to sharp borders.' 'remove very small buildings.'
#  'Convert multiple areas into a single area.'
#  'Turn buildings with small details into integrated buildings.'
#  'remove buildings with small areas.'
#  'Convert curved borders to sharp borders.' 'remove very small buildings.'
#  'Convert buildings that are too close together into one building.'
#  'Place small buildings that are too close together further apart.'
#  'Connect very small, close-together buildings.'
#  'You can see some small parcels very close to each other. Try to put distance between them and omit the parcels which remain very small ( under 25 m2)'
#  'Omit the parcels less than 25 m2'
#  'You can see some small parcels( less than 25 m2) attached to eachother. Try to put distance of 5 meter between them'
#  'Try to clean the map by deleting small parcels less than 25 m2'
#  '1. The big parcels remain the same( if they are bigger than the average size)\n2. Small parcels join to the similar parcels close to them.( less than 6meter)If they are completely different in shape dont join them by extending the parcels\n3. At the end no parcel should remain wiyh area less than 300 m2'
#  'Remove the very small parcels less than 10 m2'
#  'Find the parcels less than 10 m2 which are in distance of 5-7 meter to similar parcel. Then put the same parcel in between those to parcels. So when you look you see them extended as a line'
#  'Remove the small building.' 'Remove the noise in map'
#  'Merge the nearby buildings together.' 'Remove the small building.'
#  'Modify the sides of the building.' 'Remove the small building.'
#  'Remove the small building.' 'Modify the building’s sides.'
#  'Merge the buildings together.' 'Zoom out on the map.'
#  'smooth irregular edges of building' 'Zoom out on the map.'
#  'Merge the buildings together.' 'Merge the buildings together.'
#  'Merge the buildings together.' 'Add spacing around the building.'
#  'Add spacing around the building.' 'Add spacing around the building.'
#  'Separating polygons and creating paths between buildings with a large polygon length on one side'
#  'remove spacing around the building.' 'Zoom out on the map.'
#  'Reshape the polygon of buildings and connect the starting point to the end of existing polygons. If the length of one side is more than twice its length and if both sides are equal or close in size, maintain or create a 90-degree angle.'
#  'remove small polygons, smaller than (e.g 100m^2)'
#  'Regularize existing polygon blocks' 'merging neighbor polygons in map'
#  'merge neighbor polygons with similar geometric shapes and maintaining a minimum number of (e.g 5) polygons in each area (e.g 1000 m^2)'
#  'merge polygons with a distance of less than e.g 10 meters'
#  'remove small (e.g less than 5 m^2)  polygons in map'
#  'Remove the small building on the map.'
#  'Remove the one building on the map.'
#  'Create distance from the building.'
#  'Changing the distance of rectangular polygons at the bottom of the map and bring it closer to the adjacent rectangle'
#  'If more than 4 polygons are stuck together, convert them into groups of less than 5 ( >= 4 ) polygons and create a gap between them.'
#  'Delete small polygons or merge them to a nearby larger polygon.'
#  'Simplifying polygon shapes in a map'
#  'merging adjacent polygons on the map so that each polygon is more than 5 meters away from its adjacent polygon.'
#  'Simplifying shape outlines and making shapes smoother and reducing the jagged edges of shapes'
#  'remove small polygons in map'
#  'smoothing shapes and connect the adjacent edges with preserving areas'
#  'smoothing polygons that exist in edges of the map'
#  'Remove quadrilateral polygons, except quadrilateral polygons with an area greater than 12 square meters.'
#  'Merging neighbor polygons if the largest sides of both polygons are more than 80% adjacent to each other.'
#  'merging neighbor polygons if the distance between them is less than 5 meters or make a connection between them'
#  'Merging neighbor polygons if one of the largest sides of both polygons are more than 80% adjacent to each other.'
#  'genrelize the map by keeping only the main polygons and make it look simpler.'
#  'give me a more precise version of the map in which the units are separated well.'
#  'export a version in which the units are attached to each other without borders.'
#  'remove very small polygons'
#  'simply the shape of the polygons. remove edges.'
#  'generalize the map by keeping only the main polygons'
#  'convert the map to a version in which the units are attached to each other.'
#  'Reduce the number of vertices in the polygon geometries.'
#  'remove very small shapes.'
#  'simplify the map by removing small shapes and keeping the main ones.'
#  'simplify the shapes by merging them together.'
#  'simplify the shapes by merging them together'
#  'Reduce the polygonal complexity.' 'add more spaces between shapes'
#  'reduce complexity by merging small shapes'
#  'simplify the shapes by removing unnecessary vertices'
#  'simplify the map by  removing unnecessary vertices'
#  'generalize the map by merging the shapes.'
#  'add more distance between shapes'
#  'generalize the map by removing unnecessary shapes'
#  'generalize the map by merging the shapes'
#  'generalize the map by removing small shapes'
#  'can you increase the distance between the units a bit ?'
#  'generalize the map by reducing unnecessary vertices and merging when necessary'
#  'can you remove the borders inside each unit in order to make them appear as a whole unit?'
#  'can you separate the units and move them from each other?'
#  'can you separate each unit in a more precise way?'
#  'please export a more generalized version of the map'
#  'remove the borders between the units'
#  'remove the borders in the units that are attached to each other'
#  'remove the small units (comparing to the size of other units) from the map'
#  'remove the borders inside the units in order to make them appear as a whole'
#  'remove the borders inside the units and attach the units beside each other in order to make them bigger'
#  'attach all the small units beside each other, in order to make them look as a single unit'
#  'remove the small units, keep the biggest ones'
#  'remove the small units comparing to the whole units we have.'
#  'remove the smallest units from the map'
#  'convert the shape of the units into a more triangular version'
#  'remove the small units' 'increase the distance between the units'
#  'increase the distance between the units'
#  'Remove the polygon in the bottom-left corner'
#  'Remove all small buildings from the map'
#  'Merge adjacent or very close building polygons into larger continuous building blocks'
#  'Merge polygons that are very close to each other.'
#  'Merge polygons that are very close to each other'
#  'Remove small buildings/polygons from the map'
#  'Remove small buildings/polygons from the map'
#  'Make building polygons sharper'
#  'You can write:\n\n> **"Remove small polygons and slightly displace some of the buildings."**'
#  'Remove buildings that are closely spaced in consecutive rows'
#  'Merge polygons that are very close to each other'
#  'Merge polygons that are very close to each other'
#  'Remove small polygons between rows' 'Remove very small polygons'
#  'Generalize a new and clean map of the buildings by simplifying polygons, aggregating nearby buildings, and removing small, irregular features.'
#  'Merge nearby building footprints to produce a cleaner map while keeping the overall pattern.'
#  'Slightly enlarge small buildings and increase their spacing while preserving overall position and orientation.'
#  'Enlarge small buildings, adjust their shapes into more regular forms, and increase the spacing between the clustered ones. Remove insignificant fragments and slightly reposition some of the small buildings for better visual clarity. Maintain the overall pattern and spatial structure.'
#  'Reduce the number of small buildings by removing very small structures and details, and increase the spacing between them. Clean up minor geometry and keep major buildings unchanged.'
#  'Apply building displacement, adjust orientations, and regularize them while keeping the overall layout and density.'
#  'Simplify the buildings by sharpening and smoothing irregular edges.'
#  'Eliminate minor details, and simplify the outlines of the buildings, keeping their positions and sizes the same.'
#  'Remove many of the tiny buildings and keep only the medium and large ones. Reduce overall building density while preserving the main structure of the area.'
#  "Reduce very small buildings and simplify each building's outline to a cleaner and more regular shape."
#  'Simplify the shapes of the small buildings by merging them with nearby buildings. Reduce small geometric details and smooth their outlines.'
#  'Merge very close buildings, remove very small structures, and smooth complex outlines. Keep the overall layout and main building shapes recognizable.'
#  'Remove small buildings and eliminate narrow and tiny shapes. Keep the larger buildings to create a cleaner, less cluttered map.'
#  'Remove tiny, insignificant buildings and smooth irregular shapes while keeping the overall layout.'
#  'Smooth and simplify outlines of the buildings, remove fine geometric details, and regularize edges and right angles.'
#  'Remove tiny polygons and smooth small irregularities of the remaining buildings.'
#  'Reduce small gaps between adjacent buildings and lightly regularize the shapes, and allow slight overlap where needed.'
#  'Merge nearby small buildings into larger simplified shapes, and smooth the outline of the remaining buildings while slightly reducing the gaps between them.'
#  'Smooth and sharpen the outlines and edges of the buildings, making them slightly more regular.'
#  'Remove some of the small buildings to increase spacing between them. Reduce density but keep every building in the same place.'
#  'Slightly regularize the shapes of the buildings and fix small uneven edges.'
#  'Lightly simplify and regularize the buildings and remove small geometric noise, while keeping the original shapes and sizes.'
#  "Eliminate small and isolated buildings that aren't important."
#  'Make each building more regular and clean in shape by smoothing rough edges and irregular outlines.'
#  'Remove the gap between adjacent building blocks'
#  'Place adjacent buildings together so that the numbers are even and space the extra building further apart'
#  'Create a gap between the pair of buildings close together in the southeast of the map'
#  'Convert polygonal building blocks to at most 4-sided without changing the area.'
#  'Turn adjacent buildings into integrated blocks'
#  'Zoom in on the map a bit and isolate buildings that are between 100 meters long and 100 to 200 meters wide'
#  'Given a map of several building blocks, refine the shapes by removing unnecessary edges while preserving the total area of each block. Simplify each block to the minimum number of corners possible without altering its overall footprint'
#  'Merge all buildings with an area below 100 m² into their nearest adjacent block. After merging, regularize the resulting shapes as much as possible while preserving overall area and spatial continuity'
#  'Identify all building blocks larger than 300 m² that share a boundary and merge each adjacent group into a single unified block while preserving total area and spatial consistency'
#  'Identify all building blocks larger than 200 m² that share a boundary and merge each adjacent group into a single unified block while preserving total area and spatial consistency'
#  'Remove all buildings with an area below 50 m² from the map while keeping the remaining block geometry intact.'
#  'Detach all buildings under 50 m² that are directly attached to larger blocks, separating their geometry from the adjacent blocks without altering the main block shapes'
#  'Combine all buildings that are physically touching into a single unified block, ensuring the merged geometry remains clean and topologically consistent'
#  'Remove all buildings with an area below 50 m² from the map while keeping the remaining block geometry intact'
#  'Identify all buildings with irregular or asymmetric shapes and optimize each one into a simplified form with the minimum number of edges possible, while strictly preserving the original area'
#  'Detach all buildings under 50 m² that are directly attached to larger blocks, separating their geometry from the adjacent blocks without altering the main block shapes'
#  'Given a map of several building blocks, refine the shapes by removing unnecessary edges while preserving the total area of each block. Simplify each block to the minimum number of corners possible without altering its overall footprint'
#  'Relocate all standalone buildings under 100 m² by shifting them toward the nearest neighboring block until they become directly attached, ensuring spatial alignment without altering their area'
#  'Merge all adjacent or touching buildings into a single unified block, ensuring clean geometry and consistent boundaries'
#  'Identify all adjacent buildings with equal area and merge each matching group into a single unified block while preserving overall geometry continuity'
#  'Remove all buildings with an area below 100 m² from the map while keeping the remaining block geometry intact'
#  'Keep all buildings, but slightly shrink the footprints and apply small position shifts in dense areas to increase the spacing between neighboring buildings.']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["step1_is_prompt"] & (df["step1_lang"] == "en"), "step2_text"] = df.loc[
# 100%|██████████| 13/13 [00:08<00:00,  1.47it/s]
# Saved: step2_translated.csv and step2_translated.xlsx

# %%
GRAMMAR_SYSTEM = "You perform minimal grammatical correction without changing tone or meaning."

GRAMMAR_USER_TEMPLATE = """Correct grammar, punctuation, spacing, and number formatting in the sentence.

Rules:
- Do NOT change meaning.
- Do NOT change tone.
- Do NOT paraphrase.
- Do NOT add/remove content unless grammatically required.
- Keep it as ONE sentence prompt.
- Output ONE line only.

Text:
{TEXT}
"""

def minimal_grammar_fix(text: str, model="gpt-4o-mini") -> str:
    if text is None or not isinstance(text, str) or not text.strip():
        return np.nan
    msg = GRAMMAR_USER_TEMPLATE.format(TEXT=text.strip())
    r = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role":"system", "content": GRAMMAR_SYSTEM},
            {"role":"user", "content": msg},
        ],
    )
    return r.choices[0].message.content.strip()


IN3_XLSX = DATA_DIR / "step2_translated.xlsx"
df = pd.read_excel(IN3_XLSX)

df["step3_text"] = df["step2_text"].progress_apply(minimal_grammar_fix)
df["cleaned_text"] = df["step3_text"]

OUT3_CSV  = DATA_DIR / "step3_cleaned.csv"
OUT3_XLSX = DATA_DIR / "step3_cleaned.xlsx"
df.to_csv(OUT3_CSV, index=False)
df.to_excel(OUT3_XLSX, index=False)

print("Saved:", OUT3_CSV.name, "and", OUT3_XLSX.name)
# Out:
# 100%|██████████| 786/786 [07:54<00:00,  1.66it/s]
# Saved: step3_cleaned.csv and step3_cleaned.xlsx

# %%
TH_EXIST_SYSTEM = "You are a strict binary classifier for map-generalization prompts."

# IMPORTANT: escape JSON braces with {{ and }} because we use .format()
TH_EXIST_USER = """Determine whether the prompt contains a threshold/constraint condition (explicit or implicit).

Return ONLY a JSON object with exactly these keys:
{{
  "threshold_exist": true/false,
  "evidence": "short phrase indicating the threshold, or empty string if none"
}}

Prompt:
{TEXT}
"""

def detect_threshold_llm(text: str, model="gpt-4o-mini"):
    if text is None or (isinstance(text, float) and np.isnan(text)):
        return {"threshold_exist": False, "evidence": ""}

    t = str(text).strip()
    if not t:
        return {"threshold_exist": False, "evidence": ""}

    r = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role": "system", "content": TH_EXIST_SYSTEM},
            {"role": "user", "content": TH_EXIST_USER.format(TEXT=t)},
        ],
        response_format={"type": "json_object"},
    )

    try:
        obj = json.loads(r.choices[0].message.content)
    except Exception:
        return {"threshold_exist": False, "evidence": ""}

    # normalize keys defensively
    obj = {str(k).strip().replace('"', ""): v for k, v in (obj or {}).items()}

    return {
        "threshold_exist": bool(obj.get("threshold_exist", False)),
        "evidence": "" if obj.get("evidence", "") is None else str(obj.get("evidence", "")).strip(),
    }

# %%
IN4_XLSX = DATA_DIR / "step3_cleaned.xlsx"
df = pd.read_excel(IN4_XLSX)

# Apply only on non-empty cleaned_text to save API calls
mask = df["cleaned_text"].notna()

results = pd.Series([{"threshold_exist": False, "evidence": ""}] * len(df), index=df.index)
results.loc[mask] = df.loc[mask, "cleaned_text"].progress_apply(detect_threshold_llm)

df["threshold_exist"] = results.apply(lambda x: x["threshold_exist"])
df["threshold_evidence"] = results.apply(lambda x: x["evidence"])

OUT4_CSV  = DATA_DIR / "step4_threshold_exist.csv"
OUT4_XLSX = DATA_DIR / "step4_threshold_exist.xlsx"
df.to_csv(OUT4_CSV, index=False)
df.to_excel(OUT4_XLSX, index=False)

print("Saved:", OUT4_CSV.name, "and", OUT4_XLSX.name)
# Out:
# 100%|██████████| 617/617 [08:39<00:00,  1.19it/s]
# Saved: step4_threshold_exist.csv and step4_threshold_exist.xlsx

# %%
TH_KNOWN_SYSTEM = "You are a strict classifier for threshold specification in map-generalization prompts."

# IMPORTANT: escape JSON braces because we use .format()
TH_KNOWN_USER = """The prompt below contains a threshold/constraint.

Decide whether the threshold is KNOWN or UNKNOWN.

KNOWN:
- numeric threshold (e.g., 10 meters, 200 m², 5 buildings)
- qualitative but explicit threshold (e.g., very small buildings, closely spaced, short distance)

UNKNOWN:
- placeholder/vague threshold (e.g., X meters, N, some distance, a threshold, less than the threshold)

Return ONLY a JSON object with exactly these keys:
{{
  "threshold_known": true/false,
  "evidence": "If threshold_known is true: copy the short phrase that specifies the threshold. Otherwise: empty string."
}}

Prompt:
{TEXT}
"""

def threshold_known_llm(text: str, model="gpt-4o-mini"):
    if text is None or (isinstance(text, float) and np.isnan(text)):
        return {"threshold_known": False, "evidence": ""}

    t = str(text).strip()
    if not t:
        return {"threshold_known": False, "evidence": ""}

    r = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role": "system", "content": TH_KNOWN_SYSTEM},
            {"role": "user", "content": TH_KNOWN_USER.format(TEXT=t)},
        ],
        response_format={"type": "json_object"},
    )

    try:
        raw = json.loads(r.choices[0].message.content)
    except Exception:
        return {"threshold_known": False, "evidence": ""}

    # normalize keys (defensive)
    raw = {str(k).strip().replace('"', ""): v for k, v in (raw or {}).items()}

    known = bool(raw.get("threshold_known", False))
    evidence = raw.get("evidence", "")
    evidence = "" if evidence is None else str(evidence).strip()

    # enforce your rule
    if not known:
        evidence = ""

    return {"threshold_known": known, "evidence": evidence}

# %%
IN5_XLSX = DATA_DIR / "step4_threshold_exist.xlsx"
df = pd.read_excel(IN5_XLSX)

# create columns
if "threshold_known" not in df.columns:
    df["threshold_known"] = pd.NA
if "threshold_known_evidence" not in df.columns:
    df["threshold_known_evidence"] = ""

mask = (df["threshold_exist"] == True) & df["cleaned_text"].notna()

results = df.loc[mask, "cleaned_text"].progress_apply(threshold_known_llm)

df.loc[mask, "threshold_known"] = results.apply(lambda x: x["threshold_known"]).values
df.loc[mask, "threshold_known_evidence"] = results.apply(lambda x: x["evidence"]).values

# enforce your rule: if threshold_exist True, threshold_known must be True/False
mask_bad = (df["threshold_exist"] == True) & (df["threshold_known"].isna())
df.loc[mask_bad, "threshold_known"] = False
df.loc[mask_bad, "threshold_known_evidence"] = ""

OUT5_CSV  = DATA_DIR / "step5_threshold_known.csv"
OUT5_XLSX = DATA_DIR / "step5_threshold_known.xlsx"
df.to_csv(OUT5_CSV, index=False)
df.to_excel(OUT5_XLSX, index=False)

print("Saved:", OUT5_CSV.name, "and", OUT5_XLSX.name)
# Out:
# 100%|██████████| 434/434 [04:48<00:00,  1.50it/s]
# Saved: step5_threshold_known.csv and step5_threshold_known.xlsx
